# %%
import math
x1,y1,x2,y2,x3,y3 = eval(input("Enter three points:"))

a = math.sqrt((x3-x2)**2+(y3-y2)**2)
b = math.sqrt((x3-x1)**2+(y3-y1)**2)
c = math.sqrt((x1-x2)**2+(y1-y2)**2)

A = round(math.degrees(math.acos((a*a-b*b-c*c)/(-2*b*c))),2)
B = round(math.degrees(math.acos((b*b-a*a-c*c)/(-2*a*c))),2)
C = round(math.degrees(math.acos((c*c-a*a-b*b)/(-2*a*b))),2)
print("The three angles are %.2f %.2f %.2f" %(A,B,C))
# Out:
# The three angles are 90.00 53.13 36.87

# %%
import math
x1,y1,x2,y2=eval(input("Enter the latitude and longitude of two points in degrees:"))
x1 = math.radians (x1)
y1 = math.radians (y1)
x2 = math.radians (x2)
y2 = math.radians (y2)
d = 6371.018*math.acos(math.sin(x1)*math.sin(x2)+math.cos(x1)*math.cos(x2)*math.cos(y1-y2))
print(f"The great circle distance of two point is {d:.2f}km.")
# Out:
# The great circle distance of two point is 20015.14km.

# %%
poem = """My kitty cat likes %s,
My kitty cat likes %s,
My kitty cat fell on his %s
And now thinks he's a %s."""
print(poem % ('roast beef', 'ham', 'head', 'clam'))
# Out:
# My kitty cat likes roast beef,
# My kitty cat likes ham,
# My kitty cat fell on his head
# And now thinks he's a clam.

# %%
letter = """Dear {salutation} {name},

Thank you for your letter. We are sorry that our {product}
{verbed} in your {room}. Please note that it should never
be used in a {room}, especially near any {animals}.

Send us your receipt and {amount} for shipping and handling.
We will send you another {product} that, in our tests,
is {percent}% less likely to have {verbed}.

Thank you for your support.

Sincerely,

{spokesman}
{job_title}"""

salutation = "Mr."
name = "Chen"
product = "toaster"
verbed = "exploded"  
room = "kitchen"
animals = "cats"
amount = "$50"
percent = 20
spokesman = "John Doe"
job_title = "Customer Service Manager"

result = letter.format(
    salutation=salutation, 
    name=name, 
    product=product, 
    verbed=verbed, 
    room=room, 
    animals=animals, 
    amount=amount, 
    percent=percent, 
    spokesman=spokesman, 
    job_title=job_title
)

print(result)
# Out:
# Dear Mr. Chen,
#
# Thank you for your letter. We are sorry that our toaster
# exploded in your kitchen. Please note that it should never
# be used in a kitchen, especially near any cats.
#
# Send us your receipt and $50 for shipping and handling.
# We will send you another toaster that, in our tests,
# is 20% less likely to have exploded.
#
# Thank you for your support.
#
# Sincerely,
#
# John Doe
# Customer Service Manager

# %%
song = """When an eel grabs your arm,
And it causes great harm,
That's - a moray!"""

words = [word.capitalize() if word.startswith('m') else word for word in song.split()]
result = " ".join(words)

print(result)
# Out:
# When an eel grabs your arm, And it causes great harm, That's - a Moray!

# %%
data = input()
fruit_list = data.split(",") 
clean_list = [fruit.strip() for fruit in fruit_list]
result = "-".join(clean_list)
print(result)
# Out:
# 蘋果-香蕉-鳳梨-水蜜桃

# %%
password = input()
if len(password) > 0:
    if password[0].isupper()!=1:
        print("The first character must be uppercase.")
    if password.isupper():
        print("The password cannot be all uppercase.")
    if len(password) < 7 or len(password) > 12:
        print("The password must be between 7 and 12 characters.")
else:
        middle_stars = "*" * (len(password) - 3)
        password = password[:2] + middle_stars + password[-1:]
        print(f"{password=}")
# Out:
# The first character must be uppercase.
# The password must be between 7 and 12 characters.
